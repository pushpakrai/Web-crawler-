# %%
import requests
from bs4 import BeautifulSoup
from collections import deque
import time

class WebCrawler:
    def __init__(self, start_url, max_pages):
        self.start_url = start_url
        self.max_pages = max_pages
        self.visited = set()
        self.queue = deque()
        self.stack = []
        self.use_bfs = True
        self.total_time = 0
        self.num_crawls = 0

    def crawl(self):
        start_time = time.time()
        if self.use_bfs:
            self.queue.append(self.start_url)
            while self.queue and len(self.visited) < self.max_pages:
                current_url = self.queue.popleft()
                if current_url not in self.visited:
                    self.visited.add(current_url)
                    print("Crawling:", current_url)
                    self.parse_url(current_url)
        else:
            self.stack.append(self.start_url)
            while self.stack and len(self.visited) < self.max_pages:
                current_url = self.stack.pop()
                if current_url not in self.visited:
                    self.visited.add(current_url)
                    print("Crawling:", current_url)
                    self.parse_url(current_url)
        end_time = time.time()
        crawl_time = end_time - start_time
        self.total_time += crawl_time
        self.num_crawls += 1
        return crawl_time

    def parse_url(self, url):
        try:
            response = requests.get(url)
            if response.status_code == 200:
                soup = BeautifulSoup(response.text, "html.parser")
                # Extract links from the page
                links = [link.get("href") for link in soup.find_all("a", href=True)]
                self.enqueue_links(links) if self.use_bfs else self.push_links(links)
        except Exception as e:
            print("Failed to crawl:", url)
            print(e)

    def enqueue_links(self, links):
        for link in links:
            if link and link not in self.visited:
                self.queue.append(link)

    def push_links(self, links):
        for link in links:
            if link and link not in self.visited:
                self.stack.append(link)

    def switch_algorithm(self):
        self.use_bfs = not self.use_bfs

    def average_crawl_time(self):
        return self.total_time / self.num_crawls if self.num_crawls > 0 else 0

# Example usage:
crawler = WebCrawler("https://kayak.com", 20)

# Crawling using BFS
for _ in range(5):
    crawl_time = crawler.crawl()
    print(f"Time taken for BFS crawl: {crawl_time:.2f} seconds")

# After crawling with BFS, switch to DFS
crawler.switch_algorithm()

# Crawling using DFS
for _ in range(5):
    crawl_time = crawler.crawl()
    print(f"Time taken for DFS crawl: {crawl_time:.2f} seconds")

print(f"Average time taken to crawl: {crawler.average_crawl_time():.2f} seconds")
# Out:
# Crawling: https://kayak.com
# Crawling: #Vp0X-pageContent
# Failed to crawl: #Vp0X-pageContent
# Invalid URL '#Vp0X-pageContent': No scheme supplied. Perhaps you meant https://#Vp0X-pageContent?
# Crawling: /
# Failed to crawl: /
# Invalid URL '/': No scheme supplied. Perhaps you meant https:///?
# Crawling: /flights
# Failed to crawl: /flights
# Invalid URL '/flights': No scheme supplied. Perhaps you meant https:///flights?
# Crawling: /stays
# Failed to crawl: /stays
# Invalid URL '/stays': No scheme supplied. Perhaps you meant https:///stays?
# Crawling: /cars
# Failed to crawl: /cars
# Invalid URL '/cars': No scheme supplied. Perhaps you meant https:///cars?
# Crawling: /packages
# Failed to crawl: /packages
# Invalid URL '/packages': No scheme supplied. Perhaps you meant https:///packages?
# Crawling: /trains
# Failed to crawl: /trains
# Invalid URL '/trains': No scheme supplied. Perhaps you meant https:///trains?
# Crawling: #
# Failed to crawl: #
# Invalid URL '#': No scheme supplied. Perhaps you meant https://#?
# Crawling: https://www.kayak.com.ar/
# Crawling: https://www.kayak.com.au/
# Crawling: https://www.be.kayak.com/
# Crawling: https://www.kayak.bo/
# Crawling: https://www.kayak.com.br/
# Crawling: https://www.ca.kayak.com/
# Crawling: https://www.kayak.cl/
# Crawling: https://www.cn.kayak.com/
# Crawling: https://www.kayak.com.co/
# Crawling: https://www.kayak.co.cr/
# Crawling: https://www.kayak.dk/
# Time taken for BFS crawl: 13.09 seconds
# Time taken for BFS crawl: 0.00 seconds
# Time taken for BFS crawl: 0.00 seconds
# Time taken for BFS crawl: 0.00 seconds
# Time taken for BFS crawl: 0.00 seconds
# Time taken for DFS crawl: 0.00 seconds
# Time taken for DFS crawl: 0.00 seconds
# Time taken for DFS crawl: 0.00 seconds
# Time taken for DFS crawl: 0.00 seconds
# Time taken for DFS crawl: 0.00 seconds
# Average time taken to crawl: 1.31 seconds

# %%
import requests
from bs4 import BeautifulSoup
from collections import deque
import time
from urllib.parse import urlparse, urljoin

class WebCrawler:
    def __init__(self, start_url, max_pages):
        self.start_url = start_url
        self.max_pages = max_pages
        self.visited = set()
        self.queue = deque()
        self.stack = []
        self.use_bfs = True
        self.total_time = 0
        self.num_crawls = 0

    def crawl(self):
        start_time = time.time()
        if self.use_bfs:
            self.queue.append(self.start_url)
            while self.queue and len(self.visited) < self.max_pages:
                current_url = self.queue.popleft()
                if current_url not in self.visited:
                    self.visited.add(current_url)
                    print("Crawling:", current_url)
                    self.parse_url(current_url)
        else:
            self.stack.append(self.start_url)
            while self.stack and len(self.visited) < self.max_pages:
                current_url = self.stack.pop()
                if current_url not in self.visited:
                    self.visited.add(current_url)
                    print("Crawling:", current_url)
                    self.parse_url(current_url)
        end_time = time.time()
        crawl_time = end_time - start_time
        self.total_time += crawl_time
        self.num_crawls += 1
        return crawl_time

    def parse_url(self, url):
        try:
            response = requests.get(url)
            if response.status_code == 200:
                soup = BeautifulSoup(response.text, "html.parser")
                # Extract links from the page
                links = [link.get("href") for link in soup.find_all("a", href=True)]
                valid_links = self.filter_valid_links(links, url)
                self.enqueue_links(valid_links) if self.use_bfs else self.push_links(valid_links)
        except Exception as e:
            print("Failed to crawl:", url)
            print(e)

    def filter_valid_links(self, links, base_url):
        valid_links = []
        for link in links:
            parsed = urlparse(link)
            if parsed.scheme and parsed.netloc:  # Absolute URL
                valid_links.append(link)
            else:  # Relative URL - construct absolute URL
                absolute_url = urljoin(base_url, link)
                valid_links.append(absolute_url)
        return valid_links

    def enqueue_links(self, links):
        for link in links:
            if link and link not in self.visited:
                self.queue.append(link)

    def push_links(self, links):
        for link in links:
            if link and link not in self.visited:
                self.stack.append(link)

    def switch_algorithm(self):
        self.use_bfs = not self.use_bfs

    def average_crawl_time(self):
        return self.total_time / self.num_crawls if self.num_crawls > 0 else 0

# Example usage:
crawler = WebCrawler("https://kayak.com", 20)

# Crawling using BFS
for _ in range(5):
    crawl_time = crawler.crawl()
    print(f"Time taken for BFS crawl: {crawl_time:.2f} seconds")

# After crawling with BFS, switch to DFS
crawler.switch_algorithm()

# Crawling using DFS
for _ in range(5):
    crawl_time = crawler.crawl()
    print(f"Time taken for DFS crawl: {crawl_time:.2f} seconds")

print(f"Average time taken to crawl: {crawler.average_crawl_time():.2f} seconds")
# Out:
# Crawling: https://kayak.com
# Crawling: https://kayak.com#PFTl-pageContent
# Crawling: https://kayak.com/
# Crawling: https://kayak.com/flights
# Crawling: https://kayak.com/stays
# Crawling: https://kayak.com/cars
# Crawling: https://kayak.com/packages
# Crawling: https://kayak.com/trains
# Crawling: https://www.kayak.com.ar/
# Crawling: https://www.kayak.com.au/
# Crawling: https://www.be.kayak.com/
# Crawling: https://www.kayak.bo/
# Crawling: https://www.kayak.com.br/
# Crawling: https://www.ca.kayak.com/
# Crawling: https://www.kayak.cl/
# Crawling: https://www.cn.kayak.com/
# Crawling: https://www.kayak.com.co/
# Crawling: https://www.kayak.co.cr/
# Crawling: https://www.kayak.dk/
# Crawling: https://www.kayak.de/
# Time taken for BFS crawl: 24.77 seconds
# Time taken for BFS crawl: 0.00 seconds
# Time taken for BFS crawl: 0.00 seconds
# Time taken for BFS crawl: 0.00 seconds
# Time taken for BFS crawl: 0.00 seconds
# Time taken for DFS crawl: 0.00 seconds
# Time taken for DFS crawl: 0.00 seconds
# Time taken for DFS crawl: 0.00 seconds
# Time taken for DFS crawl: 0.00 seconds
# Time taken for DFS crawl: 0.00 seconds
# Average time taken to crawl: 2.48 seconds

# %%
import requests
from bs4 import BeautifulSoup
from collections import deque
import time
from urllib.parse import urlparse, urljoin

# %%
import requests
from bs4 import BeautifulSoup
from collections import deque
import time
from urllib.parse import urlparse, urljoin

class WebCrawler:
    def __init__(self, start_url, max_pages):
        self.start_url = start_url
        self.max_pages = max_pages
        self.visited = set()
        self.queue = deque()
        self.use_bfs = True
        self.total_time = 0
        self.num_crawls = 0

    def crawl(self):
        start_time = time.time()
        while len(self.visited) < self.max_pages:
            if self.use_bfs and self.queue:
                current_url = self.queue.popleft()
            elif not self.use_bfs and self.queue:
                current_url = self.queue.pop()
            else:
                break
            if current_url not in self.visited:
                try:
                    self.visited.add(current_url)
                    print("Crawling:", current_url)
                    self.parse_url(current_url)
                except Exception as e:
                    print(f"Failed to crawl: {current_url} - {e}")
        end_time = time.time()
        crawl_time = end_time - start_time
        self.total_time += crawl_time
        self.num_crawls += 1
        return crawl_time

    def parse_url(self, url):
        try:
            response = requests.get(url)
            if response.status_code == 200:
                soup = BeautifulSoup(response.text, "html.parser")
                # Extract links from the page
                links = [link.get("href") for link in soup.find_all("a", href=True)]
                valid_links = self.filter_valid_links(links, url)
                self.enqueue_links(valid_links)
        except Exception as e:
            print("Failed to crawl:", url)
            print(e)

    def filter_valid_links(self, links, base_url):
        valid_links = []
        for link in links:
            parsed = urlparse(link)
            if parsed.scheme and parsed.netloc:  # Absolute URL
                valid_links.append(link)
            else:  # Relative URL - construct absolute URL
                absolute_url = urljoin(base_url, link)
                valid_links.append(absolute_url)
        return valid_links

    def enqueue_links(self, links):
        for link in links:
            if link and link not in self.visited:
                self.queue.append(link)

    def switch_algorithm(self):
        self.use_bfs = not self.use_bfs
        if not self.use_bfs:
            print("Switching from BFS to DFS")

    def average_crawl_time(self):
        return self.total_time / self.num_crawls if self.num_crawls > 0 else 0

# Example usage:
crawler = WebCrawler("https://kayak.com", 20)

# Crawling
for _ in range(10):
    crawl_time = crawler.crawl()
    print(f"Time taken for crawl: {crawl_time:.2f} seconds")
    if crawler.num_crawls % 5 == 0:
        crawler.switch_algorithm()

print(f"Average time taken to crawl the full website: {crawler.average_crawl_time():.2f} seconds")
# Out:
# Time taken for crawl: 0.00 seconds
# Time taken for crawl: 0.00 seconds
# Time taken for crawl: 0.00 seconds
# Time taken for crawl: 0.00 seconds
# Time taken for crawl: 0.00 seconds
# Switching from BFS to DFS
# Time taken for crawl: 0.00 seconds
# Time taken for crawl: 0.00 seconds
# Time taken for crawl: 0.00 seconds
# Time taken for crawl: 0.00 seconds
# Time taken for crawl: 0.00 seconds
# Average time taken to crawl the full website: 0.00 seconds

# %%
import requests
from bs4 import BeautifulSoup
from collections import deque
import time

# Function to get all links from a page
def get_links(url):
    try:
        response = requests.get(url)
        soup = BeautifulSoup(response.text, 'html.parser')
        links = [link.get('href') for link in soup.find_all('a', href=True)]
        return links, soup.title.text if soup.title else "No Title Found"
    except Exception as e:
        print(f"Error getting links from {url}: {e}")
        return [], "No Title Found"

# Function for dynamically adaptive crawling
def dynamic_crawl(seed_url, max_depth):
    visited = set()
    pages_to_visit = deque([(seed_url, 1)])  # Queue to track URL and depth
    total_time = 0
    num_pages = 0
    use_bfs = True  # Start with BFS

    while pages_to_visit:
        current_url, depth = pages_to_visit.popleft()
        if current_url not in visited and depth <= max_depth:
            visited.add(current_url)
            start_time = time.time()
            links, title = get_links(current_url)
            end_time = time.time()
            elapsed_time = end_time - start_time
            total_time += elapsed_time
            num_pages += 1

            print(f"Crawling {current_url} at depth {depth} - Elapsed Time: {elapsed_time:.2f} seconds - Title: {title}")

            # Switch to DFS if the number of links exceeds a threshold
            if use_bfs and len(links) > 10:
                use_bfs = False
                print("Switching from BFS to DFS")

            # You might perform specific actions here based on the page content
            # For example, print the title of the page
            print(f"Title of {current_url}: {title}")

            # Add links to visit based on the chosen algorithm (BFS/DFS)
            for link in links:
                if link and link.startswith('http') and link not in visited:
                    if use_bfs:
                        pages_to_visit.append((link, depth + 1))
                    else:
                        pages_to_visit.appendleft((link, depth + 1))

    return total_time / num_pages if num_pages > 0 else 0

# Example usage
seed_url = 'https://kayak.com'
max_crawl_depth = 3  # Set the maximum depth to crawl

start_time_total = time.time()
avg_time = dynamic_crawl(seed_url, max_crawl_depth)
end_time_total = time.time()
total_elapsed_time = end_time_total - start_time_total

print(f"Total time taken: {total_elapsed_time:.2f} seconds")
print(f"Average time per page: {avg_time:.2f} seconds")
# Out:
# Crawling https://kayak.com at depth 1 - Elapsed Time: 1.74 seconds - Title: Search Flights, Hotels & Rental Cars | KAYAK
# Switching from BFS to DFS
# Title of https://kayak.com: Search Flights, Hotels & Rental Cars | KAYAK
# Crawling https://apps.apple.com/us/app/kayak-flights-hotels-cars/id305204535 at depth 2 - Elapsed Time: 1.19 seconds - Title:
#       âKAYAK: Flights, Hotels & Cars on the AppÂ Store
#
# Title of https://apps.apple.com/us/app/kayak-flights-hotels-cars/id305204535:
#       âKAYAK: Flights, Hotels & Cars on the AppÂ Store
#
# Crawling https://www.apple.com/sitemap/ at depth 3 - Elapsed Time: 1.20 seconds - Title: Site Map - Apple
# Title of https://www.apple.com/sitemap/: Site Map - Apple
# Crawling https://www.apple.com/legal/ at depth 3 - Elapsed Time: 0.91 seconds - Title: Apple - Legal
# Title of https://www.apple.com/legal/: Apple - Legal
# Crawling https://www.apple.com/us/shop/goto/help/sales_refunds at depth 3 - Elapsed Time: 3.04 seconds - Title: Sales Policies - Apple
# Title of https://www.apple.com/us/shop/goto/help/sales_refunds: Sales Policies - Apple
# Crawling https://www.apple.com/legal/internet-services/terms/site.html at depth 3 - Elapsed Time: 0.65 seconds - Title: Legal - Website Terms of Use - Apple
# Title of https://www.apple.com/legal/internet-services/terms/site.html: Legal - Website Terms of Use - Apple
# Crawling https://www.apple.com/legal/privacy/ at depth 3 - Elapsed Time: 0.64 seconds - Title: Legal - Privacy Policy - Apple
# Title of https://www.apple.com/legal/privacy/: Legal - Privacy Policy - Apple
# Crawling https://www.apple.com/choose-country-region/ at depth 3 - Elapsed Time: 0.64 seconds - Title: Choose your country or region - Apple
# Title of https://www.apple.com/choose-country-region/: Choose your country or region - Apple
# Crawling https://locate.apple.com/ at depth 3 - Elapsed Time: 2.06 seconds - Title: Find Locations
# Title of https://locate.apple.com/: Find Locations
# Crawling https://www.apple.com/retail/ at depth 3 - Elapsed Time: 0.66 seconds - Title: Apple Store - Find a Store - Apple
# Title of https://www.apple.com/retail/: Apple Store - Find a Store - Apple
# Crawling https://apps.apple.com/us/app/cheap-flights-wayaway/id606870241 at depth 3 - Elapsed Time: 1.07 seconds - Title:
#       âCheap flights - WayAway on the AppÂ Store
#
# Title of https://apps.apple.com/us/app/cheap-flights-wayaway/id606870241:
#       âCheap flights - WayAway on the AppÂ Store
#
# Crawling https://apps.apple.com/us/app/kiwi-com-book-cheap-flights/id657843853 at depth 3 - Elapsed Time: 1.06 seconds - Title:
#       âKiwi.com: Book Cheap Flights on the AppÂ Store
#
# Title of https://apps.apple.com/us/app/kiwi-com-book-cheap-flights/id657843853:
#       âKiwi.com: Book Cheap Flights on the AppÂ Store
#
# Crawling https://apps.apple.com/us/app/skyscanner-travel-deals/id415458524 at depth 3 - Elapsed Time: 0.91 seconds - Title:
#       âSkyscanner â travel deals on the AppÂ Store
#
# Title of https://apps.apple.com/us/app/skyscanner-travel-deals/id415458524:
#       âSkyscanner â travel deals on the AppÂ Store
#
# Crawling https://apps.apple.com/us/app/last-minute-cheap-flights/id952459926 at depth 3 - Elapsed Time: 0.86 seconds - Title:
#       âLast Minute â Cheap Flights on the AppÂ Store
#
# Title of https://apps.apple.com/us/app/last-minute-cheap-flights/id952459926:
#       âLast Minute â Cheap Flights on the AppÂ Store
#
# Crawling https://apps.apple.com/us/app/cheapflights-flights-hotels/id773105628 at depth 3 - Elapsed Time: 0.84 seconds - Title:
#       âCheapflights: Flights & Hotels on the AppÂ Store
#
# Title of https://apps.apple.com/us/app/cheapflights-flights-hotels/id773105628:
#       âCheapflights: Flights & Hotels on the AppÂ Store
#
# Crawling https://apps.apple.com/us/app/momondo-flights-hotels-cars/id436736538 at depth 3 - Elapsed Time: 1.01 seconds - Title:
#       âmomondo: Flights, Hotels, Cars on the AppÂ Store
#
# Title of https://apps.apple.com/us/app/momondo-flights-hotels-cars/id436736538:
#       âmomondo: Flights, Hotels, Cars on the AppÂ Store
#
# Crawling https://apps.apple.com/us/app/mundi-voos-hot%C3%A9is-e-carros/id600097979 at depth 3 - Elapsed Time: 1.00 seconds - Title:
#       âMundi: Voos, HotÃ©is e Carros on the AppÂ Store
#
# Title of https://apps.apple.com/us/app/mundi-voos-hot%C3%A9is-e-carros/id600097979:
#       âMundi: Voos, HotÃ©is e Carros on the AppÂ Store
#
# Crawling https://apps.apple.com/us/app/checkfelix-fl%C3%BCge-hotels-autos/id492728058 at depth 3 - Elapsed Time: 1.02 seconds - Title:
#       âcheckfelix: FlÃ¼ge Hotels Autos on the AppÂ Store
#
# Title of https://apps.apple.com/us/app/checkfelix-fl%C3%BCge-hotels-autos/id492728058:
#       âcheckfelix: FlÃ¼ge Hotels Autos on the AppÂ Store
#
# Crawling https://apps.apple.com/us/app/swoodoo-fl%C3%BCge-hotels-autos/id362070846 at depth 3 - Elapsed Time: 1.02 seconds - Title:
#       âSWOODOO: FlÃ¼ge, Hotels & Autos on the AppÂ Store
#
# Title of https://apps.apple.com/us/app/swoodoo-fl%C3%BCge-hotels-autos/id362070846:
#       âSWOODOO: FlÃ¼ge, Hotels & Autos on the AppÂ Store
#
# Crawling https://www.kayak.com/privacy at depth 3 - Elapsed Time: 1.20 seconds - Title: KAYAK - Privacy Policy
# Title of https://www.kayak.com/privacy: KAYAK - Privacy Policy
# Crawling https://www.kayak.com/feedback/form at depth 3 - Elapsed Time: 0.84 seconds - Title: We ♥ Feedback
# Title of https://www.kayak.com/feedback/form: We ♥ Feedback
# Crawling https://www.kayak.com/mobile at depth 3 - Elapsed Time: 0.93 seconds - Title: KAYAK Mobile on iOS and Android - search for cheap flights, hotels and cheap travel deals on your mobile device.
# Title of https://www.kayak.com/mobile: KAYAK Mobile on iOS and Android - search for cheap flights, hotels and cheap travel deals on your mobile device.
# Crawling https://itunes.apple.com/us/genre/id6003 at depth 3 - Elapsed Time: 0.77 seconds - Title: Travel - App Store Downloads on iTunes
# Title of https://itunes.apple.com/us/genre/id6003: Travel - App Store Downloads on iTunes
# Crawling https://apps.apple.com/story/id1538632801 at depth 3 - Elapsed Time: 0.82 seconds - Title:
#       âLearn More About App Privacy : App Store Story
#
# Title of https://apps.apple.com/story/id1538632801:
#       âLearn More About App Privacy : App Store Story
#
Busca vuelos, hoteles y autos de alquiler | KAYAK
# Crawling https://www.be.kayak.com/ at depth 3 - Elapsed Time: 0.97 seconds - Title: Zoek naar vluchten, hotels en huurauto's | KAYAK
# Title of https://www.be.kayak.com/: Zoek naar vluchten, hotels en huurauto's | KAYAK
# Crawling https://www.kayak.com.au/ at depth 3 - Elapsed Time: 1.00 seconds - Title: Search Flights, Hotels & Car Hire | KAYAK
# Title of https://www.kayak.com.au/: Search Flights, Hotels & Car Hire | KAYAK
# Crawling https://www.kayak.com.ar/ at depth 3 - Elapsed Time: 0.97 seconds - Title: Buscá vuelos, hoteles y autos de alquiler | KAYAK
# Title of https://www.kayak.com.ar/: Buscá vuelos, hoteles y autos de alquiler | KAYAK
# Total time taken: 127.26 seconds
# Average time per page: 1.11 seconds

# %%
import requests
from bs4 import BeautifulSoup
from collections import deque
import time

# Function to get all links from a page
def get_links(url):
    try:
        response = requests.get(url)
        soup = BeautifulSoup(response.text, 'html.parser')
        links = [link.get('href') for link in soup.find_all('a', href=True)]
        return links, soup.title.text if soup.title else "No Title Found"
    except Exception as e:
        print(f"Error getting links from {url}: {e}")
        return [], "No Title Found"

# Function for dynamically adaptive crawling with prioritized URL ordering
def prioritized_crawl(seed_url, max_depth):
    visited = set()
    pages_to_visit = deque([(seed_url, 1)])  # Queue to track URL and depth
    total_time = 0
    num_pages = 0
    use_bfs = True  # Start with BFS

    while pages_to_visit:
        current_url, depth = pages_to_visit.popleft()
        if current_url not in visited and depth <= max_depth:
            visited.add(current_url)
            start_time = time.time()
            links, title = get_links(current_url)
            end_time = time.time()
            elapsed_time = end_time - start_time
            total_time += elapsed_time
            num_pages += 1

            print(f"Crawling {current_url} at depth {depth} - Elapsed Time: {elapsed_time:.2f} seconds - Title: {title}")

            # Switch to DFS if the number of links exceeds a threshold
            if use_bfs and len(links) > 10:
                use_bfs = False
                print("Switching from BFS to DFS")

            # Sort links based on URL length before adding to the queue
            sorted_links = sorted(links, key=lambda x: len(x))

            # Add links to visit based on the chosen algorithm (BFS/DFS)
            for link in sorted_links:
                if link and link.startswith('http') and link not in visited:
                    if use_bfs:
                        pages_to_visit.append((link, depth + 1))
                    else:
                        pages_to_visit.appendleft((link, depth + 1))

    return total_time / num_pages if num_pages > 0 else 0

# Example usage with prioritized URL ordering
seed_url = 'https://kayak.com'
max_crawl_depth = 3  # Set the maximum depth to crawl

start_time_total = time.time()
avg_time = prioritized_crawl(seed_url, max_crawl_depth)
end_time_total = time.time()
total_elapsed_time = end_time_total - start_time_total

print(f"Total time taken: {total_elapsed_time:.2f} seconds")
print(f"Average time per page: {avg_time:.2f} seconds")
# Out:
# Crawling https://kayak.com at depth 1 - Elapsed Time: 1.50 seconds - Title: Search Flights, Hotels & Rental Cars | KAYAK
# Switching from BFS to DFS
# Crawling https://apps.apple.com/us/app/kayak-flights-hotels-cars/id305204535 at depth 2 - Elapsed Time: 1.10 seconds - Title:
#       âKAYAK: Flights, Hotels & Cars on the AppÂ Store
#
# Crawling https://apps.apple.com/us/app/kayak-flights-hotels-cars/id305204535?eventid=6472814118 at depth 3 - Elapsed Time: 0.85 seconds - Title:
#       âKAYAK Price Alerts: Stop the what-ifs and start your happy dance.
#
# Crawling https://apps.apple.com/us/app/checkfelix-fl%C3%BCge-hotels-autos/id492728058 at depth 3 - Elapsed Time: 1.07 seconds - Title:
#       âcheckfelix: FlÃ¼ge Hotels Autos on the AppÂ Store
#
# Crawling https://apps.apple.com/us/app/mundi-voos-hot%C3%A9is-e-carros/id600097979 at depth 3 - Elapsed Time: 1.06 seconds - Title:
#       âMundi: Voos, HotÃ©is e Carros on the AppÂ Store
#
# Crawling https://apps.apple.com/us/app/swoodoo-fl%C3%BCge-hotels-autos/id362070846 at depth 3 - Elapsed Time: 1.11 seconds - Title:
#       âSWOODOO: FlÃ¼ge, Hotels & Autos on the AppÂ Store
#
# Crawling https://apps.apple.com/us/app/kiwi-com-book-cheap-flights/id657843853 at depth 3 - Elapsed Time: 0.93 seconds - Title:
#       âKiwi.com: Book Cheap Flights on the AppÂ Store
#
# Crawling https://apps.apple.com/us/app/cheapflights-flights-hotels/id773105628 at depth 3 - Elapsed Time: 0.95 seconds - Title:
#       âCheapflights: Flights & Hotels on the AppÂ Store
#
# Crawling https://apps.apple.com/us/app/momondo-flights-hotels-cars/id436736538 at depth 3 - Elapsed Time: 0.91 seconds - Title:
#       âmomondo: Flights, Hotels, Cars on the AppÂ Store
#
# Crawling https://apps.apple.com/us/app/last-minute-cheap-flights/id952459926 at depth 3 - Elapsed Time: 0.98 seconds - Title:
#       âLast Minute â Cheap Flights on the AppÂ Store
#
# Crawling https://apps.apple.com/us/app/skyscanner-travel-deals/id415458524 at depth 3 - Elapsed Time: 1.04 seconds - Title:
#       âSkyscanner â travel deals on the AppÂ Store
#
# Crawling https://apps.apple.com/us/app/cheap-flights-wayaway/id606870241 at depth 3 - Elapsed Time: 1.02 seconds - Title:
#       âCheap flights - WayAway on the AppÂ Store
#
# Crawling https://www.apple.com/legal/internet-services/terms/site.html at depth 3 - Elapsed Time: 0.60 seconds - Title: Legal - Website Terms of Use - Apple
# Crawling https://apps.apple.com/us/charts/iphone/travel-apps/6003 at depth 3 - Elapsed Time: 0.96 seconds - Title:
#       âTop iPhone Travel apps on the AppÂ Store - Apple
#
# Crawling https://www.apple.com/us/shop/goto/help/sales_refunds at depth 3 - Elapsed Time: 2.01 seconds - Title: Sales Policies - Apple
# Crawling https://apps.apple.com/us/developer/kayak/id305204538 at depth 3 - Elapsed Time: 0.86 seconds - Title:
#       âKAYAK Apps on the AppÂ Store
#
# Crawling https://www.apple.com/us/shop/goto/us/shop/goto/bag at depth 3 - Elapsed Time: 1.55 seconds - Title: Page Not Found - Apple
# Crawling https://www.apple.com/us/shop/goto/buy_accessories at depth 3 - Elapsed Time: 2.09 seconds - Title: Apple Accessories for Apple Watch, iPhone, iPad, and Mac - Apple
# Crawling https://www.apple.com/choose-country-region/ at depth 3 - Elapsed Time: 0.66 seconds - Title: Choose your country or region - Apple
# Crawling https://apps.apple.com/story/id1538632801 at depth 3 - Elapsed Time: 0.77 seconds - Title:
#       âLearn More About App Privacy : App Store Story
#
# Crawling https://itunes.apple.com/us/genre/id6003 at depth 3 - Elapsed Time: 1.48 seconds - Title: Travel - App Store Downloads on iTunes
# Crawling https://www.apple.com/us/shop/goto/store at depth 3 - Elapsed Time: 2.31 seconds - Title: Apple Store Online - Apple
Busca vuelos, hoteles y autos de alquiler | KAYAK
# Crawling https://www.kayak.com/ at depth 3 - Elapsed Time: 1.03 seconds - Title: Search Flights, Hotels & Rental Cars | KAYAK
# Crawling https://www.kayak.sa/ at depth 3 - Elapsed Time: 1.05 seconds - Title: البحث عن رحلات الطيران والفنادق وسيارات الاستئجار | KAYAK
# Crawling https://www.kayak.ae/ at depth 3 - Elapsed Time: 1.16 seconds - Title: Search Flights, Hotels & Car Hire | KAYAK
# Crawling https://www.kayak.se/ at depth 3 - Elapsed Time: 1.00 seconds - Title: Sök efter billiga flygresor, hotell & hyrbilar | KAYAK
# Crawling https://www.kayak.sg/ at depth 3 - Elapsed Time: 0.92 seconds - Title: Search Flights, Hotels & Rental Cars | KAYAK
# Crawling https://www.kayak.ch/ at depth 3 - Elapsed Time: 1.04 seconds - Title: Flüge, Hotels & Mietwagen finden | KAYAK
# Crawling https://www.kayak.pt/ at depth 3 - Elapsed Time: 1.47 seconds - Title: Pesquisa voos, hotéis e aluguer de carros | KAYAK
# Crawling https://www.kayak.pl/ at depth 3 - Elapsed Time: 1.05 seconds - Title: Tanie loty, hotele i samochody | KAYAK
# Crawling https://www.kayak.no/ at depth 3 - Elapsed Time: 1.08 seconds - Title: Søk etter billige flybilletter, hoteller og leiebiler | KAYAK
# Crawling https://www.kayak.nl/ at depth 3 - Elapsed Time: 0.91 seconds - Title: Zoek naar vluchten, hotels en huurauto's | KAYAK
# Crawling https://www.kayak.it/ at depth 3 - Elapsed Time: 1.20 seconds - Title: Trova voli, hotel e auto a noleggio | KAYAK
# Crawling https://www.kayak.ie/ at depth 3 - Elapsed Time: 1.12 seconds - Title: Search Flights, Hotels & Car Hire | KAYAK
# Crawling https://www.kayak.fr/ at depth 3 - Elapsed Time: 1.11 seconds - Title: Recherchez des vols, hôtels & voitures de location | KAYAK
# Crawling https://www.kayak.es/ at depth 3 - Elapsed Time: 1.13 seconds - Title: Busca vuelos, hoteles y coches de alquiler | KAYAK
# Crawling https://www.kayak.de/ at depth 3 - Elapsed Time: 1.30 seconds - Title: Flüge, Hotels & Mietwagen finden | KAYAK
# Crawling https://www.kayak.dk/ at depth 3 - Elapsed Time: 1.17 seconds - Title: Flybilletter, hoteller og biludlejning | Søg med KAYAK
# Crawling https://www.kayak.cl/ at depth 3 - Elapsed Time: 1.03 seconds - Title: Busca vuelos, hoteles y autos de alquiler | KAYAK
# Crawling https://www.kayak.bo/ at depth 3 - Elapsed Time: 1.06 seconds - Title: Busca vuelos, hoteles y autos de alquiler | KAYAK
# Total time taken: 118.35 seconds
# Average time per page: 1.03 seconds

# %% [markdown]
# TEMP

# %%
import requests
from bs4 import BeautifulSoup
from collections import deque
import time

# Function to get all links from a page
def get_links(url):
    try:
        response = requests.get(url)
        soup = BeautifulSoup(response.text, 'html.parser')
        links = [link.get('href') for link in soup.find_all('a', href=True)]
        return links, soup.title.text if soup.title else "No Title Found", soup.get_text()
    except Exception as e:
        print(f"Error getting links from {url}: {e}")
        return [], "No Title Found", ""

# Function for dynamically adaptive crawling with prioritized URL ordering and search frequency
def prioritized_crawl_with_frequency(seed_url, max_depth, search_keywords):
    visited = set()
    pages_to_visit = deque([(seed_url, 1)])  # Queue to track URL and depth
    total_time = 0
    num_pages = 0
    use_bfs = True  # Start with BFS
    keyword_frequency = {keyword: 0 for keyword in search_keywords}

    while pages_to_visit:
        current_url, depth = pages_to_visit.popleft()
        if current_url not in visited and depth <= max_depth:
            visited.add(current_url)
            start_time = time.time()
            links, title, page_text = get_links(current_url)
            end_time = time.time()
            elapsed_time = end_time - start_time
            total_time += elapsed_time
            num_pages += 1

            print(f"Crawling {current_url} at depth {depth} - Elapsed Time: {elapsed_time:.2f} seconds - Title: {title}")

            # Count keyword frequencies in page content
            for keyword in search_keywords:
                keyword_frequency[keyword] += page_text.lower().count(keyword.lower())

            # Switch to DFS if the number of links exceeds a threshold
            if use_bfs and len(links) > 10:
                use_bfs = False
                print("Switching from BFS to DFS")

            # Sort links based on URL length before adding to the queue
            sorted_links = sorted(links, key=lambda x: len(x))

            # Add links to visit based on the chosen algorithm (BFS/DFS)
            for link in sorted_links:
                if link and link.startswith('http') and link not in visited:
                    if use_bfs:
                        pages_to_visit.append((link, depth + 1))
                    else:
                        pages_to_visit.appendleft((link, depth + 1))

    return total_time / num_pages if num_pages > 0 else 0, keyword_frequency

# Example usage with prioritized URL ordering and search frequency
seed_url = 'https://kayak.com'
max_crawl_depth = 3  # Set the maximum depth to crawl
search_keywords = ['travel', 'flight', 'hotel', 'price', 'search', 'holiday', 'destination']  # Keywords to search and track frequencies

start_time_total = time.time()
avg_time, keyword_freq = prioritized_crawl_with_frequency(seed_url, max_crawl_depth, search_keywords)
end_time_total = time.time()
total_elapsed_time = end_time_total - start_time_total

print(f"Total time taken: {total_elapsed_time:.2f} seconds")
print(f"Average time per page: {avg_time:.2f} seconds")
print("Keyword Frequencies:")
for keyword, frequency in keyword_freq.items():
    print(f"{keyword.capitalize()}: {frequency}")
# Out:
# Crawling https://kayak.com at depth 1 - Elapsed Time: 1.61 seconds - Title: Search Flights, Hotels & Rental Cars | KAYAK
# Switching from BFS to DFS
# Crawling https://apps.apple.com/us/app/kayak-flights-hotels-cars/id305204535 at depth 2 - Elapsed Time: 0.74 seconds - Title:
#       âKAYAK: Flights, Hotels & Cars on the AppÂ Store
#
# Crawling https://apps.apple.com/us/app/kayak-flights-hotels-cars/id305204535?eventid=6472814118 at depth 3 - Elapsed Time: 0.64 seconds - Title:
#       âKAYAK Price Alerts: Stop the what-ifs and start your happy dance.
#
# Crawling https://apps.apple.com/us/app/checkfelix-fl%C3%BCge-hotels-autos/id492728058 at depth 3 - Elapsed Time: 0.74 seconds - Title:
#       âcheckfelix: FlÃ¼ge Hotels Autos on the AppÂ Store
#
# Crawling https://apps.apple.com/us/app/mundi-voos-hot%C3%A9is-e-carros/id600097979 at depth 3 - Elapsed Time: 0.93 seconds - Title:
#       âMundi: Voos, HotÃ©is e Carros on the AppÂ Store
#
# Crawling https://apps.apple.com/us/app/swoodoo-fl%C3%BCge-hotels-autos/id362070846 at depth 3 - Elapsed Time: 0.95 seconds - Title:
#       âSWOODOO: FlÃ¼ge, Hotels & Autos on the AppÂ Store
#
# Crawling https://apps.apple.com/us/app/kiwi-com-book-cheap-flights/id657843853 at depth 3 - Elapsed Time: 1.05 seconds - Title:
#       âKiwi.com: Book Cheap Flights on the AppÂ Store
#
# Crawling https://apps.apple.com/us/app/cheapflights-flights-hotels/id773105628 at depth 3 - Elapsed Time: 1.22 seconds - Title:
#       âCheapflights: Flights & Hotels on the AppÂ Store
#
# Crawling https://apps.apple.com/us/app/momondo-flights-hotels-cars/id436736538 at depth 3 - Elapsed Time: 1.04 seconds - Title:
#       âmomondo: Flights, Hotels, Cars on the AppÂ Store
#
# Crawling https://apps.apple.com/us/app/last-minute-cheap-flights/id952459926 at depth 3 - Elapsed Time: 0.91 seconds - Title:
#       âLast Minute â Cheap Flights on the AppÂ Store
#
# Crawling https://apps.apple.com/us/app/skyscanner-travel-deals/id415458524 at depth 3 - Elapsed Time: 0.85 seconds - Title:
#       âSkyscanner â travel deals on the AppÂ Store
#
# Crawling https://apps.apple.com/us/app/cheap-flights-wayaway/id606870241 at depth 3 - Elapsed Time: 0.91 seconds - Title:
#       âCheap flights - WayAway on the AppÂ Store
#
# Crawling https://www.apple.com/legal/internet-services/terms/site.html at depth 3 - Elapsed Time: 0.66 seconds - Title: Legal - Website Terms of Use - Apple
# Crawling https://apps.apple.com/us/charts/iphone/travel-apps/6003 at depth 3 - Elapsed Time: 1.09 seconds - Title:
#       âTop iPhone Travel apps on the AppÂ Store - Apple
#
# Crawling https://www.apple.com/us/shop/goto/help/sales_refunds at depth 3 - Elapsed Time: 1.90 seconds - Title: Sales Policies - Apple
# Crawling https://apps.apple.com/us/developer/kayak/id305204538 at depth 3 - Elapsed Time: 0.87 seconds - Title:
#       âKAYAK Apps on the AppÂ Store
#
# Crawling https://www.apple.com/us/shop/goto/us/shop/goto/bag at depth 3 - Elapsed Time: 1.44 seconds - Title: Page Not Found - Apple
# Crawling https://www.apple.com/us/shop/goto/buy_accessories at depth 3 - Elapsed Time: 2.04 seconds - Title: Apple Accessories for Apple Watch, iPhone, iPad, and Mac - Apple
# Crawling https://www.apple.com/choose-country-region/ at depth 3 - Elapsed Time: 0.68 seconds - Title: Choose your country or region - Apple
# Crawling https://apps.apple.com/story/id1538632801 at depth 3 - Elapsed Time: 0.74 seconds - Title:
#       âLearn More About App Privacy : App Store Story
#
# Crawling https://itunes.apple.com/us/genre/id6003 at depth 3 - Elapsed Time: 0.63 seconds - Title: Travel - App Store Downloads on iTunes
# Crawling https://www.apple.com/us/shop/goto/store at depth 3 - Elapsed Time: 2.04 seconds - Title: Apple Store Online - Apple
# Crawling https://www.apple.com/legal/privacy/ at depth 3 - Elapsed Time: 0.53 seconds - Title: Legal - Privacy Policy - Apple
Busca vuelos, hoteles y autos de alquiler | KAYAK
# Crawling https://www.kayak.com/ at depth 3 - Elapsed Time: 0.92 seconds - Title: Search Flights, Hotels & Rental Cars | KAYAK
# Crawling https://www.kayak.sa/ at depth 3 - Elapsed Time: 1.46 seconds - Title: البحث عن رحلات الطيران والفنادق وسيارات الاستئجار | KAYAK
# Crawling https://www.kayak.ae/ at depth 3 - Elapsed Time: 1.11 seconds - Title: Search Flights, Hotels & Car Hire | KAYAK
# Crawling https://www.kayak.se/ at depth 3 - Elapsed Time: 1.18 seconds - Title: Sök efter billiga flygresor, hotell & hyrbilar | KAYAK
# Crawling https://www.kayak.sg/ at depth 3 - Elapsed Time: 1.04 seconds - Title: Search Flights, Hotels & Rental Cars | KAYAK
# Crawling https://www.kayak.ch/ at depth 3 - Elapsed Time: 1.05 seconds - Title: Flüge, Hotels & Mietwagen finden | KAYAK
# Crawling https://www.kayak.pt/ at depth 3 - Elapsed Time: 1.03 seconds - Title: Pesquisa voos, hotéis e aluguer de carros | KAYAK
# Crawling https://www.kayak.pl/ at depth 3 - Elapsed Time: 1.10 seconds - Title: Tanie loty, hotele i samochody | KAYAK
# Crawling https://www.kayak.no/ at depth 3 - Elapsed Time: 1.11 seconds - Title: Søk etter billige flybilletter, hoteller og leiebiler | KAYAK
# Crawling https://www.kayak.nl/ at depth 3 - Elapsed Time: 0.99 seconds - Title: Zoek naar vluchten, hotels en huurauto's | KAYAK
# Crawling https://www.kayak.it/ at depth 3 - Elapsed Time: 1.00 seconds - Title: Trova voli, hotel e auto a noleggio | KAYAK
# Crawling https://www.kayak.ie/ at depth 3 - Elapsed Time: 1.33 seconds - Title: Search Flights, Hotels & Car Hire | KAYAK
# Crawling https://www.kayak.fr/ at depth 3 - Elapsed Time: 1.14 seconds - Title: Recherchez des vols, hôtels & voitures de location | KAYAK
# Crawling https://www.kayak.es/ at depth 3 - Elapsed Time: 0.90 seconds - Title: Busca vuelos, hoteles y coches de alquiler | KAYAK
# Crawling https://www.kayak.de/ at depth 3 - Elapsed Time: 1.05 seconds - Title: Flüge, Hotels & Mietwagen finden | KAYAK
# Crawling https://www.kayak.dk/ at depth 3 - Elapsed Time: 1.20 seconds - Title: Flybilletter, hoteller og biludlejning | Søg med KAYAK
# Crawling https://www.kayak.cl/ at depth 3 - Elapsed Time: 0.97 seconds - Title: Busca vuelos, hoteles y autos de alquiler | KAYAK
# Crawling https://www.kayak.bo/ at depth 3 - Elapsed Time: 0.93 seconds - Title: Busca vuelos, hoteles y autos de alquiler | KAYAK
# Total time taken: 114.19 seconds
# Average time per page: 0.99 seconds
# Keyword Frequencies:
# Travel: 906
# Flight: 2268
# Hotel: 3457
# Price: 321
# Search: 351
# Holiday: 161
# Destination: 25

# %%
import requests
from bs4 import BeautifulSoup
from collections import deque
import time

# Function to get all links from a page
def get_links(url):
    try:
        response = requests.get(url)
        soup = BeautifulSoup(response.text, 'html.parser')
        links = [link.get('href') for link in soup.find_all('a', href=True)]
        return links, soup.title.text if soup.title else "No Title Found", soup.get_text()
    except Exception as e:
        print(f"Error getting links from {url}: {e}")
        return [], "No Title Found", ""

# Function for dynamically adaptive crawling with prioritized URL ordering, search frequency, and page ranking
def prioritized_crawl_with_frequency_and_ranking(seed_url, max_depth, search_keywords):
    visited = set()
    pages_to_visit = deque([(seed_url, 1)])  # Queue to track URL and depth
    total_time = 0
    num_pages = 0
    use_bfs = True  # Start with BFS
    keyword_frequency = {keyword: 0 for keyword in search_keywords}
    page_ranks = {}  # Dictionary to hold page ranks

    while pages_to_visit:
        current_url, depth = pages_to_visit.popleft()
        if current_url not in visited and depth <= max_depth:
            visited.add(current_url)
            start_time = time.time()
            links, title, page_text = get_links(current_url)
            end_time = time.time()
            elapsed_time = end_time - start_time
            total_time += elapsed_time
            num_pages += 1

            print(f"Crawling {current_url} at depth {depth} - Elapsed Time: {elapsed_time:.2f} seconds - Title: {title}")

            # Count keyword frequencies in page content
            for keyword in search_keywords:
                keyword_frequency[keyword] += page_text.lower().count(keyword.lower())

            # Assign page rank based on depth
            if depth not in page_ranks:
                page_ranks[depth] = []
            page_ranks[depth].append(current_url)

            # Switch to DFS if the number of links exceeds a threshold
            if use_bfs and len(links) > 10:
                use_bfs = False
                print("Switching from BFS to DFS")

            # Sort links based on URL length before adding to the queue
            sorted_links = sorted(links, key=lambda x: len(x))

            # Add links to visit based on the chosen algorithm (BFS/DFS)
            for link in sorted_links:
                if link and link.startswith('http') and link not in visited:
                    if use_bfs:
                        pages_to_visit.append((link, depth + 1))
                    else:
                        pages_to_visit.appendleft((link, depth + 1))

    # Assign scores based on page depth (page ranking)
    rank_score = max_depth
    ranked_pages = {}
    for depth in range(max_depth, 0, -1):
        if depth in page_ranks:
            for url in page_ranks[depth]:
                ranked_pages[url] = rank_score
                rank_score -= 1

    return total_time / num_pages if num_pages > 0 else 0, keyword_frequency, ranked_pages

# Example usage with prioritized URL ordering, search frequency, and page ranking
seed_url = 'https://kayak.com'
max_crawl_depth = 3  # Set the maximum depth to crawl
search_keywords = ['travel', 'flight', 'hotel', 'price', 'search', 'holiday', 'destination']  # Keywords to search and track frequencies

start_time_total = time.time()
avg_time, keyword_freq, page_ranks = prioritized_crawl_with_frequency_and_ranking(seed_url, max_crawl_depth, search_keywords)
end_time_total = time.time()
total_elapsed_time = end_time_total - start_time_total

print(f"Total time taken: {total_elapsed_time:.2f} seconds")
print(f"Average time per page: {avg_time:.2f} seconds")
print("Keyword Frequencies:")
for keyword, frequency in keyword_freq.items():
    print(f"{keyword.capitalize()}: {frequency}")

print("\nPage Ranks (Based on Depth):")
for url, rank in page_ranks.items():
    print(f"{url} - Rank: {rank}")
# Out:
# Crawling https://kayak.com at depth 1 - Elapsed Time: 1.65 seconds - Title: Search Flights, Hotels & Rental Cars | KAYAK
# Switching from BFS to DFS
# Crawling https://apps.apple.com/us/app/kayak-flights-hotels-cars/id305204535 at depth 2 - Elapsed Time: 1.12 seconds - Title:
#       âKAYAK: Flights, Hotels & Cars on the AppÂ Store
#
# Crawling https://apps.apple.com/us/app/kayak-flights-hotels-cars/id305204535?eventid=6472814118 at depth 3 - Elapsed Time: 0.85 seconds - Title:
#       âKAYAK Price Alerts: Stop the what-ifs and start your happy dance.
#
# Crawling https://apps.apple.com/us/app/checkfelix-fl%C3%BCge-hotels-autos/id492728058 at depth 3 - Elapsed Time: 0.88 seconds - Title:
#       âcheckfelix: FlÃ¼ge Hotels Autos on the AppÂ Store
#
# Crawling https://apps.apple.com/us/app/mundi-voos-hot%C3%A9is-e-carros/id600097979 at depth 3 - Elapsed Time: 0.87 seconds - Title:
#       âMundi: Voos, HotÃ©is e Carros on the AppÂ Store
#
# Crawling https://apps.apple.com/us/app/swoodoo-fl%C3%BCge-hotels-autos/id362070846 at depth 3 - Elapsed Time: 0.98 seconds - Title:
#       âSWOODOO: FlÃ¼ge, Hotels & Autos on the AppÂ Store
#
# Crawling https://apps.apple.com/us/app/kiwi-com-book-cheap-flights/id657843853 at depth 3 - Elapsed Time: 0.89 seconds - Title:
#       âKiwi.com: Book Cheap Flights on the AppÂ Store
#
# Crawling https://apps.apple.com/us/app/cheapflights-flights-hotels/id773105628 at depth 3 - Elapsed Time: 0.95 seconds - Title:
#       âCheapflights: Flights & Hotels on the AppÂ Store
#
# Crawling https://apps.apple.com/us/app/momondo-flights-hotels-cars/id436736538 at depth 3 - Elapsed Time: 0.93 seconds - Title:
#       âmomondo: Flights, Hotels, Cars on the AppÂ Store
#
# Crawling https://apps.apple.com/us/app/last-minute-cheap-flights/id952459926 at depth 3 - Elapsed Time: 0.96 seconds - Title:
#       âLast Minute â Cheap Flights on the AppÂ Store
#
# Crawling https://apps.apple.com/us/app/skyscanner-travel-deals/id415458524 at depth 3 - Elapsed Time: 0.88 seconds - Title:
#       âSkyscanner â travel deals on the AppÂ Store
#
# Crawling https://apps.apple.com/us/app/cheap-flights-wayaway/id606870241 at depth 3 - Elapsed Time: 0.93 seconds - Title:
#       âCheap flights - WayAway on the AppÂ Store
#
# Crawling https://www.apple.com/legal/internet-services/terms/site.html at depth 3 - Elapsed Time: 0.63 seconds - Title: Legal - Website Terms of Use - Apple
# Crawling https://apps.apple.com/us/charts/iphone/travel-apps/6003 at depth 3 - Elapsed Time: 0.82 seconds - Title:
#       âTop iPhone Travel apps on the AppÂ Store - Apple
#
# Crawling https://www.apple.com/us/shop/goto/help/sales_refunds at depth 3 - Elapsed Time: 1.79 seconds - Title: Sales Policies - Apple
# Crawling https://apps.apple.com/us/developer/kayak/id305204538 at depth 3 - Elapsed Time: 0.75 seconds - Title:
#       âKAYAK Apps on the AppÂ Store
#
# Crawling https://www.apple.com/us/shop/goto/us/shop/goto/bag at depth 3 - Elapsed Time: 1.14 seconds - Title: Page Not Found - Apple
# Crawling https://www.apple.com/us/shop/goto/buy_accessories at depth 3 - Elapsed Time: 1.87 seconds - Title: Apple Accessories for Apple Watch, iPhone, iPad, and Mac - Apple
# Crawling https://www.apple.com/choose-country-region/ at depth 3 - Elapsed Time: 0.59 seconds - Title: Choose your country or region - Apple
# Crawling https://apps.apple.com/story/id1538632801 at depth 3 - Elapsed Time: 0.69 seconds - Title:
#       âLearn More About App Privacy : App Store Story
#
# Crawling https://itunes.apple.com/us/genre/id6003 at depth 3 - Elapsed Time: 1.00 seconds - Title: Travel - App Store Downloads on iTunes
# Crawling https://www.apple.com/us/shop/goto/store at depth 3 - Elapsed Time: 1.66 seconds - Title: Apple Store Online - Apple
# Crawling https://www.apple.com/legal/privacy/ at depth 3 - Elapsed Time: 0.55 seconds - Title: Legal - Privacy Policy - Apple
# Crawling https://www.apple.com/ios/app-store/ at depth 3 - Elapsed Time: 0.96 seconds - Title: App Store - Apple
# Crawling https://www.apple.com/entertainment/ at depth 3 - Elapsed Time: 0.78 seconds - Title: Entertainment - Services - Apple
# Crawling https://www.kayak.com/feedback/form at depth 3 - Elapsed Time: 0.99 seconds - Title: We ♥ Feedback
# Crawling https://www.apple.com/us/search at depth 3 - Elapsed Time: 0.56 seconds - Title: Apple Store Search Results - Apple
# Crawling https://www.apple.com/sitemap/ at depth 3 - Elapsed Time: 0.86 seconds - Title: Site Map - Apple
# Crawling https://www.apple.com/tv-home/ at depth 3 - Elapsed Time: 0.76 seconds - Title: TV & Home - Apple
# Crawling https://www.apple.com/airpods/ at depth 3 - Elapsed Time: 0.69 seconds - Title: AirPods - Apple
# Crawling https://www.apple.com/retail/ at depth 3 - Elapsed Time: 0.97 seconds - Title: Apple Store - Find a Store - Apple
# Crawling https://www.kayak.com/privacy at depth 3 - Elapsed Time: 0.91 seconds - Title: KAYAK - Privacy Policy
# Crawling https://www.apple.com/iphone/ at depth 3 - Elapsed Time: 0.78 seconds - Title: iPhone - Apple
# Crawling https://www.apple.com/legal/ at depth 3 - Elapsed Time: 0.56 seconds - Title: Apple - Legal
# Crawling https://www.kayak.com/mobile at depth 3 - Elapsed Time: 0.88 seconds - Title: KAYAK Mobile on iOS and Android - search for cheap flights, hotels and cheap travel deals on your mobile device.
# Crawling https://www.apple.com/watch/ at depth 3 - Elapsed Time: 0.69 seconds - Title: Watch - Apple
# Crawling https://www.apple.com/ipad/ at depth 3 - Elapsed Time: 0.77 seconds - Title: iPad - Apple
# Crawling https://www.apple.com/mac/ at depth 3 - Elapsed Time: 0.75 seconds - Title: Mac - Apple
# Crawling https://locate.apple.com/ at depth 3 - Elapsed Time: 1.26 seconds - Title: Find Locations
# Crawling https://support.apple.com at depth 3 - Elapsed Time: 0.64 seconds - Title: Official Apple Support
# Crawling https://www.apple.com/ at depth 3 - Elapsed Time: 0.59 seconds - Title: Apple
# Crawling https://play.google.com/store/apps/details?id=com.kayak.android at depth 2 - Elapsed Time: 0.70 seconds - Title: KAYAK: Flights, Hotels & Cars - Apps on Google Play
# Crawling https://play.google.com/intl/en_us/about/play-terms.html at depth 3 - Elapsed Time: 0.59 seconds - Title:
# Crawling https://support.google.com/googleplay?p=pff_parentguide at depth 3 - Elapsed Time: 1.02 seconds - Title: Parent Guide to Google Play - Google Play Help
# Crawling https://support.google.com/googleplay/?p=report_content at depth 3 - Elapsed Time: 1.10 seconds - Title: Flag an app or review on Google Play - Android - Google Play Help
Busca vuelos, hoteles y autos de alquiler | KAYAK
# Crawling https://www.kayak.bo/ at depth 3 - Elapsed Time: 0.99 seconds - Title: Busca vuelos, hoteles y autos de alquiler | KAYAK
# Total time taken: 112.96 seconds
# Average time per page: 0.98 seconds
# Keyword Frequencies:
# Travel: 907
# Flight: 2268
# Hotel: 3458
# Price: 321
# Search: 351
# Holiday: 161
# Destination: 25
#
# Page Ranks (Based on Depth):
# https://apps.apple.com/us/app/kayak-flights-hotels-cars/id305204535?eventid=6472814118 - Rank: 3
# https://apps.apple.com/us/app/checkfelix-fl%C3%BCge-hotels-autos/id492728058 - Rank: 2
# https://apps.apple.com/us/app/mundi-voos-hot%C3%A9is-e-carros/id600097979 - Rank: 1
# https://apps.apple.com/us/app/swoodoo-fl%C3%BCge-hotels-autos/id362070846 - Rank: 0
# https://apps.apple.com/us/app/kiwi-com-book-cheap-flights/id657843853 - Rank: -1
# https://apps.apple.com/us/app/cheapflights-flights-hotels/id773105628 - Rank: -2
# https://apps.apple.com/us/app/momondo-flights-hotels-cars/id436736538 - Rank: -3
# https://apps.apple.com/us/app/last-minute-cheap-flights/id952459926 - Rank: -4
# https://apps.apple.com/us/app/skyscanner-travel-deals/id415458524 - Rank: -5
# https://apps.apple.com/us/app/cheap-flights-wayaway/id606870241 - Rank: -6
# https://www.apple.com/legal/internet-services/terms/site.html - Rank: -7
# https://apps.apple.com/us/charts/iphone/travel-apps/6003 - Rank: -8
# https://www.apple.com/us/shop/goto/help/sales_refunds - Rank: -9
# https://apps.apple.com/us/developer/kayak/id305204538 - Rank: -10
# https://www.apple.com/us/shop/goto/us/shop/goto/bag - Rank: -11
# https://www.apple.com/us/shop/goto/buy_accessories - Rank: -12
# https://www.apple.com/choose-country-region/ - Rank: -13
# https://apps.apple.com/story/id1538632801 - Rank: -14
# https://itunes.apple.com/us/genre/id6003 - Rank: -15
# https://www.apple.com/us/shop/goto/store - Rank: -16
# https://www.apple.com/legal/privacy/ - Rank: -17
# https://www.apple.com/ios/app-store/ - Rank: -18
# https://www.apple.com/entertainment/ - Rank: -19
# https://www.kayak.com/feedback/form - Rank: -20
# https://www.apple.com/us/search - Rank: -21
# https://www.apple.com/sitemap/ - Rank: -22
# https://www.apple.com/tv-home/ - Rank: -23
# https://www.apple.com/airpods/ - Rank: -24
# https://www.apple.com/retail/ - Rank: -25
# https://www.kayak.com/privacy - Rank: -26
# https://www.apple.com/iphone/ - Rank: -27
# https://www.apple.com/legal/ - Rank: -28
# https://www.kayak.com/mobile - Rank: -29
# https://www.apple.com/watch/ - Rank: -30
# https://www.apple.com/ipad/ - Rank: -31
# https://www.apple.com/mac/ - Rank: -32
# https://locate.apple.com/ - Rank: -33
# https://support.apple.com - Rank: -34
# https://www.apple.com/ - Rank: -35
# https://play.google.com/intl/en_us/about/play-terms.html - Rank: -36
# https://support.google.com/googleplay?p=pff_parentguide - Rank: -37
# https://support.google.com/googleplay/?p=report_content - Rank: -38
# https://support.google.com/googleplay/answer/7007852 - Rank: -39
# https://support.google.com/googleplay/?p=about_play - Rank: -40
# https://support.google.com/googleplay/answer/134336 - Rank: -41
# https://store.google.com/?playredirect=true - Rank: -42
# https://myaccount.google.com/termsofservice - Rank: -43
